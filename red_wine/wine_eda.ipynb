# %% [markdown]
# #### Red wine pipeline

# %%
# Core libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Preprocessing libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import joblib

# %%
# Load the dataset
path = r"C:\Users\kanyi\Desktop\practice_ml_fast_api\winequality-red.csv"
df = pd.read_csv(path, sep=";")

# %%
# display the first five dataset
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Check the data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# CHeck the unique values of the quality column
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %% [markdown]
# 1. Data Overview
#
# - This project uses a dataset of 1,599 red wine samples.
# - Each wine has 11 measurements that describe its chemical properties (acidity, sugar, and alcohol level) and a quality score (the target variable) rated between 3 and 8.
#
# - The goal is to understand what makes a wine “good” or “bad,” and prepare the data for a machine learning model that predicts wine quality.

# %%
# Check the desciptive summary of the dataset
df.describe().T.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_91c49_row0_col0, #T_91c49_row1_col0, #T_91c49_row1_col7, #T_91c49_row2_col0, #T_91c49_row2_col3, #T_91c49_row2_col4, #T_91c49_row2_col7, #T_91c49_row3_col0, #T_91c49_row4_col0, #T_91c49_row4_col1, #T_91c49_row4_col2, #T_91c49_row4_col3, #T_91c49_row4_col4, #T_91c49_row4_col5, #T_91c49_row4_col6, #T_91c49_row4_col7, #T_91c49_row5_col0, #T_91c49_row6_col0, #T_91c49_row7_col0, #T_91c49_row7_col2, #T_91c49_row7_col7, #T_91c49_row8_col0, #T_91c49_row9_col0, #T_91c49_row10_col0, #T_91c49_row11_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_91c49_row0_col1, #T_91c49_row10_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_91c49_row0_col2, #T_91c49_row0_col7, #T_91c49_row3_col1, #T_91c49_row3_col5, #T_91c49_row3_col7, #T_91c49_row8_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_91c49_row0_col3 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_91c49_row0_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_91c49_row0_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_91c49_row0_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_91c49_row1_col1, #T_91c49_row1_col5, #T_91c49_row1_col6, #T_91c49_row9_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_91c49_row1_col2, #T_91c49_row2_col1, #T_91c49_row2_col2, #T_91c49_row2_col5, #T_91c49_row2_col6, #T_91c49_row8_col2, #T_91c49_row9_col2, #T_91c49_row9_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_91c49_row1_col3, #T_91c49_row1_col4, #T_91c49_row7_col6, #T_91c49_row8_col7, #T_91c49_row9_col1, #T_91c49_row9_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_91c49_row3_col2, #T_91c49_row3_col6, #T_91c49_row7_col4, #T_91c49_row9_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_91c49_row3_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_91c49_row3_col4, #T_91c49_row8_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_91c49_row5_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_91c49_row5_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_91c49_row5_col3, #T_91c49_row7_col3, #T_91c49_row11_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_91c49_row5_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_91c49_row5_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_91c49_row5_col6 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_91c49_row5_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_91c49_row6_col1, #T_91c49_row6_col2, #T_91c49_row6_col4, #T_91c49_row6_col5, #T_91c49_row6_col6, #T_91c49_row6_col7, #T_91c49_row10_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_91c49_row6_col3 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_91c49_row7_col1, #T_91c49_row9_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_91c49_row7_col5, #T_91c49_row11_col2, #T_91c49_row11_col7 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_91c49_row8_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_91c49_row8_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_91c49_row8_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_91c49_row10_col1, #T_91c49_row11_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_91c49_row10_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_91c49_row10_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_91c49_row10_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_91c49_row10_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_91c49_row11_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_91c49_row11_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_91c49_row11_col6 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# </style>
# <table id="T_91c49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91c49_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_91c49_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_91c49_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_91c49_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_91c49_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_91c49_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_91c49_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_91c49_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91c49_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_91c49_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_91c49_row0_col1" class="data row0 col1" >8.319637</td>
#       <td id="T_91c49_row0_col2" class="data row0 col2" >1.741096</td>
#       <td id="T_91c49_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_91c49_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_91c49_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_91c49_row0_col6" class="data row0 col6" >9.200000</td>
#       <td id="T_91c49_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_91c49_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_91c49_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_91c49_row1_col1" class="data row1 col1" >0.527821</td>
#       <td id="T_91c49_row1_col2" class="data row1 col2" >0.179060</td>
#       <td id="T_91c49_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_91c49_row1_col4" class="data row1 col4" >0.390000</td>
#       <td id="T_91c49_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_91c49_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_91c49_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_91c49_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_91c49_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_91c49_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_91c49_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_91c49_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_91c49_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_91c49_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_91c49_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_91c49_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_91c49_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_91c49_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_91c49_row3_col1" class="data row3 col1" >2.538806</td>
#       <td id="T_91c49_row3_col2" class="data row3 col2" >1.409928</td>
#       <td id="T_91c49_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_91c49_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_91c49_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_91c49_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_91c49_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_91c49_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_91c49_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_91c49_row4_col1" class="data row4 col1" >0.087467</td>
#       <td id="T_91c49_row4_col2" class="data row4 col2" >0.047065</td>
#       <td id="T_91c49_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_91c49_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_91c49_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_91c49_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_91c49_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>
#       <th id="T_91c49_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_91c49_row5_col0" class="data row5 col0" >159

# %% [markdown]
# 2. What the data tells us
#
# Features
# - The alcohol, acidity and the sulphates have strong influence on the quality of the wine. The std is low which means theres low disparity between the data point
# - The features are not in the same range, hence scaling is strongly recommended.
# - The sulfur dioxides have high variability indicating they are not stable and may affect the quality of the wine.
#
# Target
# - The wine quality scores (our target variable) mostly fall between 5 and 6, meaning most wines are of average quality.
# - Only a few wines scored very low (3–4) or very high (7–8).

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(240)

# %%
# Drop the duuplicates
df.drop_duplicates(inplace=True)

# %%
# recheck the du[licates have been handled
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Reclassify the target variable
df = df.replace({'quality':{8:'Best', 7:'Good', 6:'Good', 5:'Average', 4:'Bad', 3:'Bad'}})

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4  Average
# 1      9.8  Average
# 2      9.8  Average
# 3      9.8     Good
# 5      9.4  Average

# %% [markdown]
# 3. Getting the Data Ready for Modeling
#
# - No missing or invalid values.
# - The data set consist of duplicate values and were handled by dropping them.
# - All columns were numerical (no need for encoding).
# - The target was reclassified
# - Since each feature uses different measurement units, we  will standardize them using MinMaxScaler to put them all on the same scale (0,1), so the model can learn fairly from each one.
# - We will split the data into feature and target, also train and test sets.
# - After this, the data was ready to train ML algorithm.

# %%
# Split into feature and target 
y = df['quality']
X = df.drop('quality', axis=1)

# %%
# Scale the feature columns
scaler = MinMaxScaler(feature_range=(0,1))

X_scaled = scaler.fit_transform(X)

# %%
# Split the data into train test using the scaled data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Create a dictionary to store the models
models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "DecisionTree": DecisionTreeClassifier(), 
    "KNeighbors": KNeighborsClassifier(),
    "Naive_Bayes": GaussianNB()
}

# %%
# Initialize a dictionary to store the models
results = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[model_name] = accuracy
    print(f"{model_name} Acuuracy: {accuracy}")

    # lets include confusion matrix
    cm =confusion_matrix(y_test,y_pred)
    display = ConfusionMatrixDisplay(confusion_matrix=cm)

    # plot with model name as title
    display.plot(cmap='Blues')
    plt.title(f"Confusion matrix {model_name}")
    plt.show()
# Out:
# Training LogisticRegression...
# LogisticRegression Acuuracy: 0.7095588235294118
# Training Ensemble...
# Ensemble Acuuracy: 0.7205882352941176
# Training DecisionTree...
# DecisionTree Acuuracy: 0.6029411764705882
# Training KNeighbors...
# KNeighbors Acuuracy: 0.6617647058823529
# Training Naive_Bayes...
# Naive_Bayes Acuuracy: 0.6875

# %% [markdown]
# 4. Training our model
#
# - Created a dictionary to store the number of models for the training.
# - We fed our data to the model to learn and use that for the prediction.
# - We checked the accuracy score to evaluate the model (to see how well it is predicting)
# - Based on the accuracy results and the ratio of the True Predicted to False Predicted; RandomForest performed best.
# - Recommend hyperparameter tuning to improve the performance of the model.

# %%
# Lets get the parameter for Random Forest
rf = RandomForestClassifier()
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Lets tune the Random Forest - set Hyperparameters

param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1,2,4],
        'bootstrap': [True, False]
}

# Let's define our RandomSearchCV
random_search = RandomizedSearchCV(RandomForestClassifier(random_state=234), param_distributions= param_grid, cv=5, n_jobs=1, verbose=1)
random_search.fit(X_train, y_train)
print(f"Best parameter for random Forest: {random_search.best_params_}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameter for random Forest: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 30, 'bootstrap': True}

# %%
#  Cross Validation score for the best model -Random Forest
best_model = random_search.best_estimator_
cv_scores = cross_val_score(best_model, X_scaled, y, cv=5)
print(f"Cross Validation score: {cv_scores}")
print(f"Mean Cross Validation score: {cv_scores.mean()}")
# Out:
# Cross Validation score: [0.65441176 0.66176471 0.75       0.69485294 0.67527675]
# Mean Cross Validation score: 0.6872612329064467

# %% [markdown]
# 6. Hyperparameter result
# - Set the parameters using a list to save computational time.
# - RandomSearch method was selected because it is computationally cheap, and it selects random parameters.
# - The model that performed best has these parameters - {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 30, 'bootstrap': False}
# - Cross Validation score was used to check how well the model will perform on new sets of data.
# - The average of the cross validation score is 0.67% (estimation of how the model will perform)

# %%
# Use the best model to predict
y_pred_rf = best_model.predict(X_test)
print("\n Classification Report")
print(classification_report(y_test, y_pred_rf, zero_division=1))
# Out:
#  Classification Report
#               precision    recall  f1-score   support
#
#      Average       0.71      0.72      0.72       120
#          Bad       1.00      0.00      0.00        15
#         Best       1.00      0.00      0.00         3
#         Good       0.73      0.81      0.77       134
#
#     accuracy                           0.72       272
#    macro avg       0.86      0.38      0.37       272
# weighted avg       0.74      0.72      0.70       272

# %% [markdown]
# Summary of Classification Report
#
# - The model’s overall accuracy is 72%, meaning it correctly predicted wine quality in about 3 out of every 4 samples.
#
# - Average-quality wines (most common):
# The model did well, it caught most of them correctly (recall = 0.72) and was fairly accurate when it predicted “Average” (precision = 0.72).
#
# - Good-quality wines:
# Performance was strong here too (recall = 0.81, F1 = 0.77), showing the model can identify good wines reliably.
#
# - Bad and Best wines:
# These classes have very few samples (only 15 and 3), so the model didn’t learn their patterns well; it barely recognized any of them (recall = 0.00).
# - Save the model and the scaler as .pkl for reusability

# %%
# Let's save our best model as a pickle
joblib.dump(best_model, 'Best_model.pkl')

# Let's save the scaler as a pickle
joblib.dump(scaler, 'scaler.pkl')

print("Model and Scaler have been successfully saved")
# Out:
# Model and Scaler have been successfully saved
